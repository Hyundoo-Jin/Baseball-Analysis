# %%
import pymysql
import pandas as pd
import numpy as np

# %% [markdown]
# ### 데이터 전처리
# #### sql 초기화하기

# %%
db = pymysql.connect(host = 'localhost', user = 'root', password = 'tjfdkr7242', db = 'lahman2016')
cur = db.cursor()

# %% [markdown]
# #### 데이터 가져오기

# %%
Batting = pd.read_sql('''select Batting.playerID, Batting.yearID, Batting.teamID, Batting.lgID, Batting.G, AB, R, H, 2B, 3B, HR, RBI, Batting.SB, Batting.CS, BB, SO, IBB, HBP, SH, SF, GIDP, InnOuts, PO, A, E, DP, ZR, salary
                                    from Batting join Salaries on Batting.playerID = Salaries.playerID and
                                    Batting.yearID = Salaries.yearID
                                    join Fielding on Batting.playerID = Fielding.playerID and
                                    Batting.yearID = Fielding.yearID
                                    where Salaries.yearID > 1993''', db)

# %%
Batting.head()
# Out:
#     playerID  yearID teamID lgID    G   AB   R   H  2B  3B   ...     SH  SF  \
# 0  abbotji01    1994    NYA   AL   24    0   0   0   0   0   ...      0   0
# 1  abbotku01    1994    FLO   NL  101  345  41  86  17   3   ...      3   2
# 2   acrema01    1994    OAK   AL   34    0   0   0   0   0   ...      0   0
# 3  aguilri01    1994    MIN   AL   44    0   0   0   0   0   ...      0   0
# 4  aldremi01    1994    OAK   AL   76  178  23  43   5   0   ...      0   3
#
#    GIDP  InnOuts   PO    A   E  DP ZR   salary
# 0     0      481    8   23   1   1     2775000
# 1     5     2476  162  260  15  61      109000
# 2     0      103    0    3   1   0      109000
# 3     0      134    4    9   0   0     3260000
# 4     2      552  171   14   1  15      430000
#
# [5 rows x 28 columns]

# %%
Pitching = pd.read_sql('''select Pitching.playerID, Pitching.yearID, stint, Pitching.teamID, Pitching.lgID, W, L, G, GS, CG, SHO, SV, IPouts, H, ER, HR, BB, SO, BAOpp, ERA, IBB, WP, HBP, BK, BFP, GF, R, SH, SF, GIDP, salary
                                    from Pitching join Salaries on Pitching.playerID = Salaries.playerID and
                                    Pitching.yearID = Salaries.yearID
                                    where Salaries.yearID > 1993''', db)

# %%
Pitching.head()
# Out:
#     playerID  yearID  stint teamID lgID   W  L   G  GS  CG   ...     WP  HBP  \
# 0  abbotji01    1994      1    NYA   AL   9  8  24  24   2   ...      8    2
# 1   acrema01    1994      1    OAK   AL   5  1  34   0   0   ...      1    1
# 2  aguilri01    1994      1    MIN   AL   1  4  44   0   0   ...      2    0
# 3  alvarwi01    1994      1    CHA   AL  12  8  24  24   2   ...      3    0
# 4  anderbr02    1994      1    CAL   AL   7  5  18  18   0   ...      5    5
#
#    BK  BFP  GF   R  SH  SF GIDP   salary
# 0   1  692   0  88               2775000
# 1   0  147   6  13                109000
# 2   0  201  40  23               3260000
# 3   0  682   0  72                285000
# 4   5  441   0  63                120000
#
# [5 rows x 31 columns]

# %%
Fielding = pd.read_sql('select * from Fielding where yearID > 1993', db)

# %%
Fielding.head()
# Out:
#     playerID  yearID  stint teamID lgID POS   G  GS InnOuts   PO    A   E  DP  \
# 0  abbotji01    1994      1    NYA   AL   P  24  24     481    8   23   1   1
# 1  abbotku01    1994      1    FLO   NL  SS  99  93    2476  162  260  15  61
# 2   acrema01    1994      1    OAK   AL   P  34   0     103    0    3   1   0
# 3  aguilri01    1994      1    MIN   AL   P  44   0     134    4    9   0   0
# 4  aldremi01    1994      1    OAK   AL  1B  27  20     552  171   14   1  15
#
#   PB WP SB CS ZR
# 0
# 1
# 2
# 3
# 4

# %%
Teams = pd.read_sql('''select yearID, lgID, teamID, Rank, DivWin, attendance
                                from Teams where yearID > 1993''', db)

# %%
Teams.head()
# Out:
#    yearID lgID teamID  Rank DivWin attendance
# 0    1994   NL    ATL     2           2539240
# 1    1994   AL    BAL     2           2535359
# 2    1994   AL    BOS     4           1775818
# 3    1994   AL    CAL     4           1512622
# 4    1994   AL    CHA     1           1697398

# %% [markdown]
# #### Featrue 정규화, 결측치 처리

# %%
from sklearn.preprocessing import minmax_scale, FunctionTransformer
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %% [markdown]
# ##### 투수 전처리

# %%
Pitching.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10328 entries, 0 to 10327
# Data columns (total 31 columns):
# playerID    10328 non-null object
# yearID      10328 non-null int64
# stint       10328 non-null int64
# teamID      10328 non-null object
# lgID        10328 non-null object
# W           10328 non-null int64
# L           10328 non-null int64
# G           10328 non-null int64
# GS          10328 non-null int64
# CG          10328 non-null int64
# SHO         10328 non-null int64
# SV          10328 non-null int64
# IPouts      10328 non-null int64
# H           10328 non-null int64
# ER          10328 non-null int64
# HR          10328 non-null int64
# BB          10328 non-null int64
# SO          10328 non-null int64
# BAOpp       10328 non-null object
# ERA         10328 non-null float64
# IBB         10328 non-null object
# WP          10328 non-null object
# HBP         10328 non-null object
# BK          10328 non-null int64
# BFP         10328 non-null object
# GF          10328 non-null object
# R           10328 non-null int64
# SH          10328 non-null object
# SF          10328 non-null object
# GIDP        10328 non-null object
# salary      10328 non-null int64
# dtypes: float64(1), int64(18), object(12)
# memory usage: 2.4+ MB

# %%
for colname, type in dict(Pitching.loc[:, 'G':'GIDP'].dtypes).items() :
    if type == 'object' :
        Pitching[colname].replace(to_replace = '', value = 0, inplace = True)
        Pitching[colname] = Pitching[colname].astype(np.float32)

# %%
for col in Pitching.columns :
    print(col, sum(Pitching[col] == 0))
# Out:
# playerID 0
# yearID 0
# stint 0
# teamID 0
# lgID 0
# W 1909
# L 1514
# G 0
# GS 5355
# CG 8394
# SHO 9251
# SV 7563
# IPouts 7
# H 72
# ER 165
# HR 619
# BB 152
# SO 182
# BAOpp 1118
# ERA 169
# IBB 2622
# WP 2180
# HBP 2204
# BK 8066
# BFP 0
# GF 3515
# R 161
# SH 4640
# SF 4643
# GIDP 3734
# salary 0

# %%
Pitching_numeric = Pitching.loc[:, 'G':'salary']
Pitching_numeric_scaled = minmax_scale(Pitching_numeric)
Pitching_numeric_scaled = pd.DataFrame(Pitching_numeric_scaled, index = Pitching_numeric.index, columns = Pitching_numeric.columns)

# %%
for column in Pitching_numeric_scaled.columns :
    sns.FacetGrid(Pitching_numeric_scaled, aspect = 4).map(sns.kdeplot, column, shade = True).add_legend()
    plt.show()

# %%
temp = Pitching
temp.loc[:, 'G':'salary'] = Pitching_numeric_scaled
for column in Pitching_numeric_scaled.columns :
    sns.FacetGrid(temp, hue = 'lgID', aspect = 4).map(sns.kdeplot, column, shade = True).add_legend()
    plt.show()

# %%
Pitching_numeric_scaled = temp
del temp

# %% [markdown]
# ##### 타자 전처리

# %%
Batting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34023 entries, 0 to 34022
# Data columns (total 28 columns):
# playerID    34023 non-null object
# yearID      34023 non-null int64
# teamID      34023 non-null object
# lgID        34023 non-null object
# G           34023 non-null int64
# AB          34023 non-null int64
# R           34023 non-null int64
# H           34023 non-null int64
# 2B          34023 non-null int64
# 3B          34023 non-null int64
# HR          34023 non-null int64
# RBI         34023 non-null int64
# SB          34023 non-null int64
# CS          34023 non-null int64
# BB          34023 non-null int64
# SO          34023 non-null int64
# IBB         34023 non-null object
# HBP         34023 non-null object
# SH          34023 non-null object
# SF          34023 non-null object
# GIDP        34023 non-null object
# InnOuts     34023 non-null object
# PO          34023 non-null int64
# A           34023 non-null int64
# E           34023 non-null int64
# DP          34023 non-null int64
# ZR          34023 non-null object
# salary      34023 non-null int64
# dtypes: int64(18), object(10)
# memory usage: 7.3+ MB

# %%
for colname, type in dict(Batting.loc[:, 'G':'salary'].dtypes).items() :
    if type == 'object' :
        Batting[colname].replace(to_replace = '', value = 0, inplace = True)
        Batting[colname] = Batting[colname].astype(np.float32)

# %%
for col in Batting.columns :
    print(col, sum(Batting[col] == 0))       # ZR : 수비율(지명타자 + 포수)
# Out:
# playerID 0
# yearID 0
# teamID 0
# lgID 0
# G 0
# AB 6153
# R 10398
# H 9284
# 2B 12385
# 3B 21729
# HR 15561
# RBI 11008
# SB 19349
# CS 20611
# BB 11041
# SO 7302
# IBB 22342
# HBP 18730
# SH 19324
# SF 18280
# GIDP 13741
# InnOuts 62
# PO 3910
# A 4912
# E 15607
# DP 14896
# ZR 33838
# salary 0

# %%
Batting = Batting.drop(Batting.index[Batting['AB'] == 0])    # 타석에 들어선 적이 없는 선수들 제거(투수)

# %%
Batting_numeric = Batting.loc[:, 'G':'salary']
Batting_numeric_scaled = minmax_scale(Batting_numeric)
Batting_numeric_scaled = pd.DataFrame(Batting_numeric_scaled, index = Batting_numeric.index, columns = Batting_numeric.columns)

# %%
for column in Batting_numeric_scaled.columns :
    sns.FacetGrid(Batting_numeric_scaled, aspect = 4).map(sns.kdeplot, column, shade = True).add_legend()
    plt.show()

# %%
temp = Batting
temp.loc[:, 'G':'salary'] = Batting_numeric_scaled
for column in Batting_numeric_scaled.columns :
    sns.FacetGrid(temp, hue = 'lgID', aspect = 4).map(sns.kdeplot, column, shade = True).add_legend()
    plt.show()

# %%
Batting_numeric_scaled = temp
del temp

# %% [markdown]
# #### 팀 전처리

# %%
Teams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 682 entries, 0 to 681
# Data columns (total 6 columns):
# yearID        682 non-null int64
# lgID          682 non-null object
# teamID        682 non-null object
# Rank          682 non-null int64
# DivWin        682 non-null object
# attendance    682 non-null object
# dtypes: int64(2), object(4)
# memory usage: 32.0+ KB

# %%
Teams['attendance'] = Teams['attendance'].astype(np.float32)
Teams['attendance'] = minmax_scale(Teams['attendance'])

# %%
sns.FacetGrid(Teams, hue = 'lgID', aspect = 4).map(sns.kdeplot, 'attendance', shade = True).add_legend()    #관객은 내셔널 리그가 약간 더 많음

# %% [markdown]
# #### AL, NL 나누기

# %%
Pitching['lgID'].unique()
# Out:
# array(['AL', 'NL'], dtype=object)

# %%
Pitching_AL = Pitching[Pitching['lgID'] == 'AL']
Pitching_NL = Pitching[Pitching['lgID'] == 'NL']
print(Pitching_AL.shape)
print(Pitching_NL.shape)
# Out:
# (4884, 31)
# (5444, 31)

# %%
Fielding_AL = Fielding[Fielding['lgID'] == 'AL']
Fielding_NL = Fielding[Fielding['lgID'] == 'NL']
Batting_AL = Batting[Batting['lgID'] == 'AL']
Batting_NL = Batting[Batting['lgID'] == 'NL']
print(Fielding_AL.shape, Batting_AL.shape)
print(Fielding_NL.shape, Batting_NL.shape)
# Out:
# (18993, 18) (11905, 28)
# (20886, 18) (15965, 28)

# %% [markdown]
# AL : 지명타자가 있고 투수는 공격에 참가하지 않음
# NL : 지명타자가 없고 투수도 타석에 들어서야 함

# %%
Teams_AL = Teams[Teams['lgID'] == 'AL']
Teams_NL = Teams[Teams['lgID'] == 'NL']

# %% [markdown]
# ### 선수들의 유형은? (군집분석)

# %%
from sklearn.cluster import KMeans
from sklearn.neighbors import NearestNeighbors
from sklearn import metrics
from sklearn.decomposition import PCA

# %% [markdown]
# #### 투수 분석

# %%
for i in range(2, 10) :
    kmeans_model = KMeans(n_clusters=i, random_state=1).fit(Pitching_numeric_scaled.loc[:, 'W':'GIDP'])
    labels = kmeans_model.labels_
    print(metrics.silhouette_score(Pitching_numeric_scaled.loc[:, 'W':'salary'], labels, metric='euclidean'))
# Out:
# 0.600485289749
# 0.448290174498
# 0.418495404394
# 0.413194016915
# 0.407734848196
# 0.380084113045
# 0.37365674642
# 0.378675661896

# %% [markdown]
# 적절하게 군집화가 이루어지지 않는 것처럼 보인다 -> PCA(차원축소)

# %%
pca = PCA(n_components=10)
pca.fit(Pitching_numeric_scaled.loc[:, 'G':'GIDP'])
cum_var = np.cumsum(np.round(pca.explained_variance_ratio_, decimals = 3) * 100)
print(cum_var)
# Out:
# [ 66.6  78.9  83.4  86.2  88.1  89.8  91.4  92.9  94.3  95.5]

# %%
plt.ylabel('% Variance Explained')
plt.xlabel('# of Features')
plt.title('PCA Analysis')
plt.ylim(60,100.5)
plt.style.context('seaborn-whitegrid')
plt.plot(cum_var)

# %%
pca = PCA(n_components=2)
pca.fit(Pitching_numeric_scaled.loc[:, 'G':'GIDP'])
with pd.option_context('display.max_columns', None):
    display(pd.DataFrame(pca.components_, columns = Pitching_numeric_scaled.loc[:, 'G':'GIDP'].columns))
# Out:
#           G        GS        CG       SHO        SV    IPouts         H  \
# 0  0.026541  0.477937  0.060004  0.053760 -0.029381  0.342186  0.331030
# 1  0.727525 -0.261297 -0.025547 -0.022789  0.287980  0.087102  0.033474
#
#          ER        HR        BB        SO     BAOpp       ERA       IBB  \
# 0  0.294682  0.223185  0.229591  0.181200 -0.003555 -0.008246  0.061621
# 1 -0.005910 -0.008330  0.079265  0.094112 -0.057433 -0.038036  0.196731
#
#          WP       HBP        BK       BFP        GF         R        SH  \
# 0  0.098916  0.150617  0.049980  0.358475 -0.070196  0.290474  0.116805
# 1  0.068311  0.043646  0.006386  0.082337  0.477737 -0.002983  0.060239
#
#          SF      GIDP
# 0  0.137365  0.159645
# 1  0.052842  0.053598

# %% [markdown]
# 첫 번째 주성분 : 선발투수 자격요건(많은 이닝 소화 가능)
# 두 번째 주성분 : 계투 및 마무리 투수 자격요건(많은 경기 출장, 마무리 담당)
#
# -----------------------------------------------------------------------
# ##### 세이브 수, 완봉 등과 같은 투수의 position을 짐작할 수 있는 데이터는 제외하고 분석

# %%
pca = PCA(n_components=10)
pca.fit(Pitching_numeric_scaled.loc[:, 'IPouts':'GIDP'].drop('GF', axis = 1))
cum_var = np.cumsum(np.round(pca.explained_variance_ratio_, decimals = 3) * 100)
print(cum_var)
# Out:
# [ 74.5  81.   84.4  87.   89.3  91.5  93.5  95.2  96.6  97.9]

# %%
plt.ylabel('% Variance Explained')
plt.xlabel('# of Features')
plt.title('PCA Analysis')
plt.ylim(65,100.5)
plt.style.context('seaborn-whitegrid')
plt.plot(cum_var)

# %%
pca = PCA(n_components=3)
pca.fit(Pitching_numeric_scaled.loc[:, 'IPouts':'GIDP'].drop('GF', axis = 1))
with pd.option_context('display.max_columns', None):
    display(pd.DataFrame(pca.components_, columns = Pitching_numeric_scaled.loc[:, 'IPouts':'GIDP'].drop('GF', axis = 1).columns))
# Out:
#      IPouts         H        ER        HR        BB        SO     BAOpp  \
# 0  0.391327  0.378209  0.336998  0.255009  0.265324  0.208230 -0.004964
# 1  0.077297  0.074735  0.114197  0.107201  0.127632  0.052630 -0.271179
# 2  0.038806 -0.109223 -0.191000 -0.263546  0.232456  0.129788 -0.187712
#
#         ERA       IBB        WP       HBP        BK       BFP         R  \
# 0 -0.010481  0.079482  0.116251  0.174729  0.057416  0.410256  0.332225
# 1 -0.003184 -0.044004  0.076015 -0.002395  0.087330  0.090301  0.114120
# 2 -0.069367  0.796391  0.192379  0.099281  0.107509  0.029598 -0.171454
#
#          SH        SF      GIDP
# 0  0.136447  0.161290  0.185362
# 1 -0.452453 -0.587501 -0.533763
# 2  0.178597 -0.121539 -0.009684

# %% [markdown]
# 첫 번째 주성분 : 선발투수로써의 자격요건(많은 이닝 소화)
# 두 번째 주성분 : 하위타선 처리 능력(낮은 상대 타자 타율, 희생타, 희생플라이 수)
# 세 번째 주성분 : 제구력(높은 4구 비율, 출루 허용 수)

# %%
pc = pd.DataFrame(pca.transform(Pitching_numeric_scaled.loc[:, 'IPouts':'GIDP'].drop('GF', axis = 1)), columns = ['Starter', 'Bottom', 'Control'])

# %%
for i in range(2, 10) :
    kmeans_model = KMeans(n_clusters=i, random_state=1).fit(pc)
    labels = kmeans_model.labels_
    print(metrics.silhouette_score(pc, labels, metric='euclidean'))
# Out:
# 0.629336621003
# 0.428467897167
# 0.39527629408
# 0.410097975491
# 0.341852283341
# 0.35804021564
# 0.350134879508
# 0.329817835559

# %%
k_means = KMeans(n_clusters=2, n_init=20)
k_means.fit(pc)
print(k_means.cluster_centers_)
# Out:
# [[-0.32375374 -0.00312465  0.00929891]
#  [ 0.86788156  0.00837621 -0.02492745]]

# %% [markdown]
# 첫 번째 군집 : 선발투수가 아닌 나머지 투수
# 두 번째 군집 : 선발투수

# %%
pc['clu'] = k_means.labels_

# %%
plt.scatter(pc['Starter'], pc['Bottom'], c = k_means.labels_, cmap = 'rainbow')    # 첫 번째 군집이 0번

# %%
plt.scatter(pc['Starter'], pc['Control'], c = k_means.labels_, cmap = 'rainbow')

# %%
plt.scatter(pc['Bottom'], pc['Control'], c = k_means.labels_, cmap = 'rainbow')

# %%
Pitching_numeric_scaled.index = np.arange(Pitching_numeric_scaled.shape[0])
Pitching_numeric_scaled = pd.concat([Pitching_numeric_scaled, pc], axis=1)

# %% [markdown]
# #### 타자 분석

# %%
for i in range(2, 10) :
    kmeans_model = KMeans(n_clusters=i, random_state=1).fit(Batting_numeric_scaled.loc[:, 'R':'ZR'])
    labels = kmeans_model.labels_
    print(metrics.silhouette_score(Batting_numeric_scaled.loc[:, 'R':'ZR'], labels, metric='euclidean'))
# Out:
# 0.538269877055
# 0.427018695167
# 0.383236046404
# 0.369876018613
# 0.328284742767
# 0.330736746122
# 0.291962466977
# 0.272830262615

# %%
pca = PCA(n_components=10)
pca.fit(Batting_numeric_scaled.loc[:, 'R':'ZR'])
cum_var = np.cumsum(np.round(pca.explained_variance_ratio_, decimals = 3) * 100)
print(cum_var)
# Out:
# [ 66.5  76.7  81.6  85.5  87.9  90.1  92.   93.6  94.8  95.9]

# %%
plt.ylabel('% Variance Explained')
plt.xlabel('# of Features')
plt.title('PCA Analysis')
plt.ylim(65,100.5)
plt.style.context('seaborn-whitegrid')
plt.plot(cum_var)

# %%
pca = PCA(n_components=3)
pca.fit(Batting_numeric_scaled.loc[:, 'R':'ZR'])
with pd.option_context('display.max_columns', None):
    display(pd.DataFrame(pca.components_, columns = Batting_numeric_scaled.loc[:, 'R':'ZR'].columns))
# Out:
#           R         H        2B        3B        HR       RBI        SB  \
# 0  0.346227  0.373949  0.339681  0.086947  0.180750  0.310011  0.090307
# 1 -0.182920 -0.184007 -0.194730 -0.024353 -0.142045 -0.207597 -0.002302
# 2  0.126953  0.146551  0.061819  0.208233 -0.210878 -0.143343  0.289193
#
#          CS        BB        SO       IBB       HBP        SH        SF  \
# 0  0.113191  0.157059  0.272165  0.027149  0.107136  0.027903  0.187651
# 1 -0.022202 -0.096659 -0.169233 -0.016286 -0.052042  0.088295 -0.122063
# 2  0.330985 -0.023341 -0.024001 -0.037882  0.011072  0.487625 -0.017629
#
#        GIDP   InnOuts        PO         A         E        DP        ZR
# 0  0.253901  0.417998  0.146978  0.151656  0.126142  0.144739  0.001293
# 1 -0.145745  0.578078  0.182869  0.433469  0.271931  0.340648  0.002520
# 2 -0.053485 -0.258774 -0.452933  0.365450  0.084860  0.021118 -0.008990

# %% [markdown]
# 첫 번째 주성분 : 적극적인 타격(출루, 안타, 2루타, 삼진 많음)
# 두 번째 주성분 : 수비능력(보살, 더블플레이 많음)
# 세 번째 주성분 : 빠른 주루, 외야수(도루 시도 수, 희생타 많음, PO 적음)

# %%
pc = pd.DataFrame(pca.transform(Batting_numeric_scaled.loc[:, 'R':'ZR']), columns = ['Hit', 'Defense', 'Run'])

# %%
for i in range(2, 10) :
    kmeans_model = KMeans(n_clusters=i, random_state=1).fit(pc)
    labels = kmeans_model.labels_
    print(metrics.silhouette_score(pc, labels, metric='euclidean'))
# Out:
# 0.601936383044
# 0.515542942053
# 0.452657599949
# 0.450439819078
# 0.45193391584
# 0.418335270059
# 0.410778526181
# 0.408776198036

# %%
k_means = KMeans(n_clusters=2, n_init=20)
k_means.fit(pc)
print(k_means.cluster_centers_)
# Out:
# [[ -2.67095062e-01   3.41279583e-03  -3.84461987e-04]
#  [  7.65924557e-01  -9.78656855e-03   1.10248716e-03]]

# %% [markdown]
# 첫 번째 군집 : 나머지 타자들
# 두 번째 군집 : 타격능력이 뛰어남

# %%
pc['clu'] = k_means.labels_

# %%
plt.scatter(pc['Hit'], pc['Defense'], c = pc['clu'], cmap = 'rainbow')
plt.show()

# %%
plt.scatter(pc['Hit'], pc['Run'], c = k_means.labels_, cmap = 'rainbow')

# %%
plt.scatter(pc['Defense'], pc['Run'], c = k_means.labels_, cmap = 'rainbow')

# %%
Batting_numeric_scaled.index = np.arange(Batting_numeric_scaled.shape[0])
Batting_numeric_scaled = pd.concat([Batting_numeric_scaled, pc], axis=1)

# %% [markdown]
# ### 한정된 자원으로 팀을 꾸려야 한다면? (야구는 투수 놀음? 타자가 더 중요?)

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

# %%
Pitching_numeric_scaled.groupby(['teamID', 'yearID'])['salary'].sum().unstack()
# Out:
# yearID      1994      1995      1996      1997      1998      1999      2000  \
# teamID
# ANA          NaN       NaN       NaN  0.545332  0.656684  0.721596  0.722599
# ARI          NaN       NaN       NaN       NaN  0.414779  1.103767  1.499443
# ATL     0.622891  0.746114  0.782919  0.790155  1.070931  1.147837  1.119113
# BAL     0.315203  0.571506  0.524779  0.671278  0.997506  0.904839  0.873115
# BOS     0.659195  0.489306  0.450290  0.501710  0.849381  1.232343  1.006476
# CAL     0.343833  0.500672  0.424083       NaN       NaN       NaN       NaN
# CHA     0.359065  0.390320  0.438585  0.556003  0.242103  0.282114  0.544799
# CHN     0.406535  0.306705  0.225046  0.553733  0.685035  0.937551  0.735105
# CIN     0.520386  0.675141  0.612609  0.487519  0.143839  0.519504  0.395610
# CLE     0.427189  0.532763  0.743351  0.678029  0.677576  0.781612  1.129674
# COL     0.145298  0.468291  0.323594  0.437202  0.518165  0.687898  0.761845
# DET     0.499731  0.340635  0.059758  0.161321  0.263856  0.552036  0.548499
# FLO     0.177799  0.365716  0.376212  0.639141  0.086802  0.332340  0.299444
# HOU     0.431835  0.479108  0.387826  0.187118  0.457572  0.502828  0.589815
# KCA     0.506694  0.462239  0.339341  0.411663  0.467620  0.303776  0.214937
# LAA          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# LAN     0.537214  0.603833  0.448664  0.565413  0.603326  1.044854  1.429250
# MIA          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# MIL          NaN       NaN       NaN       NaN  0.386372  0.486810  0.384254
# MIN     0.262108  0.314265  0.116947  0.224834  0.307683  0.311453  0.254112
# ML4     0.301754  0.151864  0.226855  0.392891       NaN       NaN       NaN
# MON     0.178575  0.139856  0.255571  0.207580  0.088383  0.371343  0.387533
# NYA     0.634703  0.868405  0.623873  0.780171  0.751714  1.134545  1.412103
# NYN     0.478761  0.346356  0.258156  0.548143  0.882202  1.076774  1.214046
# OAK     0.446338  0.311058  0.029643  0.066021  0.419826  0.683424  0.476802
# PHI     0.356480  0.284588  0.241186  0.295689  0.402983  0.403145  0.801511
# PIT     0.155346  0.081789  0.134855  0.045408  0.128363  0.241829  0.277249
# SDN     0.180201  0.156639  0.195965  0.435697  0.779413  0.576049  0.671890
# SEA     0.279499  0.447964  0.455763  0.646018  0.665278  0.499990  0.813277
# SFN     0.485229  0.309774  0.232093  0.623303  0.514102  0.495728  0.605272
# SLN     0.152200  0.430330  0.517619  0.699051  0.652656  0.604633  0.939994
# TBA          NaN       NaN       NaN       NaN  0.302682  0.452875  0.513545
# TEX     0.413476  0.350153  0.502119  0.600377  0.850825  0.922491  0.967529
# TOR     0.358290  0.573303  0.265007  0.689910  0.871880  0.689125  0.649418
# WAS          NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# yearID      2001      2002      2003    ...         2007      2008      2009  \
# teamID                                  ...
# ANA     0.332401  0.773347  1.091930    ...          NaN       NaN       NaN
# ARI     1.312765  1.833435  1.336242    ...     1.361590  1.258188  1.297452
# ATL     1.327597  1.249654  1.432829    ...     1.072938  2.015207  1.875640
# BAL     0.576490  0.535522  0.673087    ...     0.901953  0.513747  0.723954
# BOS     1.379283  1.597620  1.465588    ...     1.534979  1.246139  1.729607
# CAL          NaN       NaN       NaN    ...          NaN       NaN       NaN
# CHA     0.718981  0.360884  0.619592    ...     1.362698  1.689185  1.735855
# CHN     0.774447  0.790652  0.767849    ...     1.351879  1.867056  1.851707
# CIN     0.512268  0.704985  0.688628    ...     0.966931  0.912256  1.360524
# CLE     1.167437  1.249565  0.339473    ...     1.086607  1.384604  0.973074
# COL     1.172894  0.925766  0.588641    ...     0.959381  0.921346  1.400809
# DET     0.690270  0.619577  0.361163    ...     0.881036  1.400008  1.732495
# FLO     0.230975  0.430049  0.590022    ...     0.871187  0.285017  0.435681
# HOU     1.188005  0.863174  0.387279    ...     1.072634  1.057006  1.196589
# KCA     0.386367  0.457998  0.672448    ...     0.951111  0.898422  0.937278
# LAA          NaN       NaN       NaN    ...     1.520684  1.264642  1.622480
# LAN     1.943752  1.323572  1.760825    ...     1.946607  1.506988  1.830538
# MIA          NaN       NaN       NaN    ...          NaN       NaN       NaN
# MIL     0.487063  0.338786  0.393998    ...     1.138706  1.970189  1.201697
# MIN     0.763978  0.863291  1.088535    ...     0.917455  0.602171  0.829558
# ML4          NaN       NaN       NaN    ...          NaN       NaN       NaN
# MON     0.453331  0.472698  0.415904    ...          NaN       NaN       NaN
# NYA     1.506643  1.861641  2.523988    ...     1.907257  2.150557  2.078474
# NYN     1.447625  1.112868  1.428405    ...     1.450009  1.793046  1.991800
# OAK     0.389169  0.411698  0.689723    ...     0.676518  0.626163  0.226962
# PHI     0.609417  0.799135  1.018617    ...     1.659588  1.440810  1.808722
# PIT     0.517740  0.314939  0.422613    ...     0.756259  0.515476  0.497613
# SDN     0.655524  0.465659  0.537229    ...     1.000745  1.161228  0.664413
# SEA     0.858624  0.974471  1.166621    ...     1.037214  1.235885  1.454136
# SFN     0.954233  0.944443  0.807156    ...     1.063224  0.640251  1.300917
# SLN     1.168040  1.648237  1.252774    ...     1.354489  1.548174  1.378799
# TBA     0.213919  0.371530  0.075765    ...     0.337950  0.650064  0.877665
# TEX     0.732571  0.889629  0.914779    ...     0.971927  1.011827  1.017873
# TOR     0.735966  0.726105  0.528564    ...     1.296458  1.225180  1.060503
# WAS          NaN       NaN       NaN    ...     0.300477  0.419355  0.406996
#
# yearID      2010      2011      2012      2013      2014      2015      2016
# teamID
# ANA          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ARI     1.204068  0.844517  0.791706  1.223025  1.064987  0.712155  1.743593
# ATL     1.462533  1.155270  0.804901  0.992665  1.069343  1.256750  0.558585
# BAL     0.961068  0.735422  1.221945  1.052289  1.083153  1.536499  2.138800
# BOS     2.124041  2.393279  1.656390  2.851867  2.228634  1.865662  3.032615
# CAL          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# CHA     1.765133  1.924326  1.745934  1.731254  1.435210  2.336192  2.193366
# CHN     2.122374  2.026321  1.378168  2.015592  1.232647  3.167654  3.589825
# CIN     1.308489  1.017313  0.938781  1.610860  1.751923  1.503186  0.907150
# CLE     0.936493  0.492715  1.035982  1.090244  0.648306  0.805375  1.064732
# COL     1.347603  1.343498  1.079201  0.817655  1.277538  1.068651  0.795826
# DET     1.334956  1.015381  1.671080  1.733073  3.008984  2.902700  2.691997
# FLO     0.794114  0.963485       NaN       NaN       NaN       NaN       NaN
# HOU     1.066751  0.724590  1.159649  0.275349  0.626673  1.469630  1.363221
# KCA     1.169369  0.538810  0.985169  1.340558  1.218236  1.998176  2.017619
# LAA     1.773616  1.927792  2.330580  1.738812  1.789167  2.100605  1.865693
# LAN     1.610740  1.412572  2.356881  3.858512  3.107449  3.398848  3.840434
# MIA          NaN       NaN  2.055486  0.532787  0.320708  1.158645  1.285647
# MIL     1.509160  1.585712  1.567237  1.005501  1.685111  1.310875  0.699435
# MIN     1.041546  1.609513  0.852908  0.638701  1.124153  1.843893  1.888298
# ML4          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# MON          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# NYA     2.935666  2.272548  2.565509  2.388243  2.368148  2.383430  1.966919
# NYN     1.637329  0.775263  1.506326  0.630177  0.834122  1.616311  1.338649
# OAK     0.541558  0.676793  0.637804  0.580980  1.395242  1.311210  0.772949
# PHI     2.612001  2.820265  2.645802  2.891517  3.105362  1.433888  0.744778
# PIT     0.586194  0.511067  1.662172  1.320513  1.442051  1.735860  1.868452
# SDN     0.655754  0.593632  0.640154  0.965459  0.919069  1.992205  1.478712
# SEA     0.839348  0.633459  1.044939  1.148911  1.245663  1.521912  2.448196
# SFN     1.512293  1.878472  2.433604  2.730577  2.798121  3.135934  3.123955
# SLN     2.202821  1.432462  1.637272  1.227144  2.062221  1.947964  1.941595
# TBA     0.833333  0.435176  0.821371  0.722816  1.074306  0.550475  0.844340
# TEX     0.980421  1.112587  1.592499  1.553005  0.763152  1.932562  1.627919
# TOR     0.496057  0.808899  1.130291  1.919233  1.165340  1.995433  2.340700
# WAS     0.508650  0.727859  1.045802  1.545681  1.746776  2.856566  2.417142
#
# [35 rows x 23 columns]

# %%
Pitching_salaries = pd.DataFrame(Pitching_numeric_scaled.groupby(['teamID', 'yearID'])['salary'].sum().dropna(axis = 0))

# %%
Batting_salaries = pd.DataFrame(Batting_numeric_scaled.groupby(['teamID', 'yearID'])['salary'].sum().dropna(axis = 0))

# %%
Pitching_salaries.reset_index(inplace=True)
Batting_salaries.reset_index(inplace=True)

# %%
Teams_salary = pd.merge(Teams, Pitching_salaries, how = 'left', on = ['teamID', 'yearID'])
Teams_salary = pd.merge(Teams_salary, Batting_salaries, how = 'left', on = ['teamID', 'yearID'])

# %%
Teams_salary.columns = ['yearID', 'lgID', 'teamID', 'Rank', 'DivWin', 'attendance', 'salary_Pitcher', 'salary_Hitter']

# %%
X_train, X_test, y_train, y_test = train_test_split(Teams_salary[['salary_Pitcher', 'salary_Hitter']], Teams_salary['Rank'], test_size = 0.3)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((477, 2), (205, 2), (477,), (205,))

# %%
reg = linear_model.LinearRegression(fit_intercept = True, normalize = False)
reg.fit(X_train, y_train)
reg.coef_
# Out:
# array([-0.84886155,  0.1263811 ])

# %%
y_true = y_test
y_hat = reg.predict(X_test)
r2_score(y_true, y_hat), mean_squared_error(y_test, reg.predict(X_test))
# Out:
# (0.10182710465031042, 2.0192593730550543)

# %%
np.corrcoef(Teams_salary['Rank'], Teams_salary['salary_Pitcher'])[0, 1], np.corrcoef(Teams_salary['Rank'], Teams_salary['salary_Hitter'])[0, 1]
# Out:
# (-0.28626854741627583, -0.19513709890712244)

# %% [markdown]
# 회귀식의 계수에서는 투수의 연봉 합이 높을 수록, 타자의 연봉 합이 낮을 수록 순위가 낮은 것으로(1등에 가까운 것으로) 나타남
# => 다중공선성 발생 및 매우 낮은 설명력 => 상관계수로 비교해보기

# %% [markdown]
# ### 특정 선수의 적정 몸값은?

# %%
Pitching_numeric_scaled.loc[:, 'IPouts':'GIDP'].drop('GF', axis = 1)
# Out:
# Index(['playerID', 'yearID', 'stint', 'teamID', 'lgID', 'W', 'L', 'G', 'GS',
#        'CG', 'SHO', 'SV', 'IPouts', 'H', 'ER', 'HR', 'BB', 'SO', 'BAOpp',
#        'ERA', 'IBB', 'WP', 'HBP', 'BK', 'BFP', 'GF', 'R', 'SH', 'SF', 'GIDP',
#        'salary'],
#       dtype='object')

# %%
Pitching_numeric_scaled.columns
# Out:
# Index(['playerID', 'yearID', 'stint', 'teamID', 'lgID', 'W', 'L', 'G', 'GS',
#        'CG', 'SHO', 'SV', 'IPouts', 'H', 'ER', 'HR', 'BB', 'SO', 'BAOpp',
#        'ERA', 'IBB', 'WP', 'HBP', 'BK', 'BFP', 'GF', 'R', 'SH', 'SF', 'GIDP',
#        'salary'],
#       dtype='object')
